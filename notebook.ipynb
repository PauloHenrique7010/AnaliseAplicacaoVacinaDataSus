# %%
#Paulo Henrique da Silva
#Análise de imunizações nos ultimos 5 Anos, taxa de abandono, vacinas aplicadas, area de cobertura


#dados retirados de:
#https://datasus.saude.gov.br/acesso-a-informacao/imunizacoes-desde-1994/
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
doseAplicada15 = pd.read_excel('planilhas/dose_aplicada2015.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas
doseAplicada16 = pd.read_excel('planilhas/dose_aplicada2016.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas
doseAplicada17 = pd.read_excel('planilhas/dose_aplicada2017.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas
doseAplicada18 = pd.read_excel('planilhas/dose_aplicada2018.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas
doseAplicada19 = pd.read_excel('planilhas/dose_aplicada2019.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas
doseAplicada20 = pd.read_excel('planilhas/dose_aplicada2020.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas

abandono15 = pd.read_excel('planilhas/taxa_abandono2015.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas
abandono16 = pd.read_excel('planilhas/taxa_abandono2016.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas
abandono17 = pd.read_excel('planilhas/taxa_abandono2017.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas
abandono18 = pd.read_excel('planilhas/taxa_abandono2018.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas
abandono19 = pd.read_excel('planilhas/taxa_abandono2019.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas
abandono20 = pd.read_excel('planilhas/taxa_abandono2020.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas

# %%
doseAplicada15.head(5)
# Out:
#   Unidade da Federação  Doses_aplicadas
# 0                  NaN      107569432.0
# 1          11 Rondônia        1179094.0
# 2              12 Acre         485558.0
# 3          13 Amazonas        2808866.0
# 4           14 Roraima         523273.0

# %%
doseAplicada15 = doseAplicada15.rename(columns={'Unidade da Federação': 'uf', 'Doses_aplicadas': 'doses'})
doseAplicada16 = doseAplicada16.rename(columns={'Unidade da Federação': 'uf', 'Doses_aplicadas': 'doses'})
doseAplicada17 = doseAplicada17.rename(columns={'Unidade da Federação': 'uf', 'Doses_aplicadas': 'doses'})
doseAplicada18 = doseAplicada18.rename(columns={'Unidade da Federação': 'uf', 'Doses_aplicadas': 'doses'})
doseAplicada19 = doseAplicada19.rename(columns={'Unidade da Federação': 'uf', 'Doses_aplicadas': 'doses'})
doseAplicada20 = doseAplicada20.rename(columns={'Unidade da Federação': 'uf', 'Doses_aplicadas': 'doses'})

abandono15 = abandono15.rename(columns={'Unidade Federação': 'uf', 'Taxa de abandono': 'taxa_abandono'})
abandono16 = abandono16.rename(columns={'Unidade Federação': 'uf', 'Taxa de abandono': 'taxa_abandono'})
abandono17 = abandono17.rename(columns={'Unidade Federação': 'uf', 'Taxa de abandono': 'taxa_abandono'})
abandono18 = abandono18.rename(columns={'Unidade Federação': 'uf', 'Taxa de abandono': 'taxa_abandono'})
abandono19 = abandono19.rename(columns={'Unidade Federação': 'uf', 'Taxa de abandono': 'taxa_abandono'})
abandono20 = abandono20.rename(columns={'Unidade Federação': 'uf', 'Taxa de abandono': 'taxa_abandono'})

# %%
doseAplicada15 = doseAplicada15.dropna()
doseAplicada16 = doseAplicada16.dropna()
doseAplicada17 = doseAplicada17.dropna()
doseAplicada18 = doseAplicada18.dropna()
doseAplicada19 = doseAplicada19.dropna()
doseAplicada20 = doseAplicada20.dropna()

abandono15 = abandono15.dropna()
abandono16 = abandono16.dropna()
abandono17 = abandono17.dropna()
abandono18 = abandono18.dropna()
abandono19 = abandono19.dropna()
abandono20 = abandono20.dropna()

# %%
plt.rcParams['figure.figsize'] = (10,9)
plt.barh(doseAplicada15.uf,doseAplicada15.doses, color="red")
plt.ylabel('UF')
plt.xlabel('Doses aplicadas ( * 1000000)')
plt.title('Vacinas aplicadas no brasil no ano de 2015 ')
# Out:
# Text(0.5, 1.0, 'Vacinas aplicadas no brasil no ano de 2015 ')

# %%
SP15 = doseAplicada15['doses'].iloc[19]
SP16 = doseAplicada16['doses'].iloc[19]
SP17 = doseAplicada17['doses'].iloc[19]
SP18 = doseAplicada18['doses'].iloc[19]
SP19 = doseAplicada19['doses'].iloc[19]
SP20 = doseAplicada20['doses'].iloc[19]

# %%
SPAplicado = [SP15, SP16, SP17, SP18, SP19, SP20]
SPLegenda = ['2015','2016','2017','2018','2019','2020']

# %%
plt.bar(SPLegenda, SPAplicado)
plt.xlabel('Anos')
plt.ylabel('Quantidade ( * 1000000)')
plt.title('Doses aplicadas no estado de São Paulo nos ultimos 5 Anos\n')
# Out:
# Text(0.5, 1.0, 'Doses aplicadas no estado de São Paulo nos ultimos 5 Anos\n')

# %%
abandono15.head()
# Out:
#          uf  taxa_abandono
# 1      Acre      28.013719
# 2   Alagoas      18.049302
# 3     Amapá      30.910895
# 4  Amazonas      16.400293
# 5     Bahia      15.934666

# %%
plt.rcParams['figure.figsize'] = (10,9)
plt.barh(abandono15.uf,abandono15.taxa_abandono, color="purple")
plt.ylabel('UF')
plt.xlabel('Taxa de abandono em porcentagem(%)')
           
plt.title('Taxa de abandono as vacinas no brasil no ano de 2015')
# Out:
# Text(0.5, 1.0, 'Taxa de abandono as vacinas no brasil no ano de 2015')

# %%
SP15 = abandono15['taxa_abandono'].iloc[24]
SP16 = abandono16['taxa_abandono'].iloc[24]
SP17 = abandono17['taxa_abandono'].iloc[24]
SP18 = abandono18['taxa_abandono'].iloc[24]
SP19 = abandono19['taxa_abandono'].iloc[24]
SP20 = abandono20['taxa_abandono'].iloc[24]

SPAbandono = [SP15, SP16, SP17, SP18, SP19, SP20]

plt.bar(SPLegenda, SPAbandono, color = 'pink')
plt.xlabel('Anos')
plt.ylabel('Abandono em %')
plt.title('Taxa de abandono a tomar vacina no estado de São Paulo nos últimos 5 Anos\n')
# Out:
# Text(0.5, 1.0, 'Taxa de abandono a tomar vacina no estado de São Paulo nos últimos 5 Anos\n')

# %%
cobertura15 = pd.read_excel('planilhas/taxa_cobertura2015.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas
cobertura16 = pd.read_excel('planilhas/taxa_cobertura2016.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas
cobertura17 = pd.read_excel('planilhas/taxa_cobertura2017.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas
cobertura18 = pd.read_excel('planilhas/taxa_cobertura2018.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas
cobertura19 = pd.read_excel('planilhas/taxa_cobertura2019.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas
cobertura20 = pd.read_excel('planilhas/taxa_cobertura2020.xlsx', skiprows = range(0, 4)) # pula as primeiras 5 linhas

cobertura15 = cobertura15.rename(columns={'Unidade da Federação': 'uf', 'Coberturas Vacinais': 'cobertura'})
cobertura16 = cobertura16.rename(columns={'Unidade da Federação': 'uf', 'Coberturas Vacinais': 'cobertura'})
cobertura17 = cobertura17.rename(columns={'Unidade da Federação': 'uf', 'Coberturas Vacinais': 'cobertura'})
cobertura18 = cobertura18.rename(columns={'Unidade da Federação': 'uf', 'Coberturas Vacinais': 'cobertura'})
cobertura19 = cobertura19.rename(columns={'Unidade da Federação': 'uf', 'Coberturas Vacinais': 'cobertura'})
cobertura20 = cobertura20.rename(columns={'Unidade da Federação': 'uf', 'Coberturas Vacinais': 'cobertura'})

cobertura15 = cobertura15.dropna()
cobertura16 = cobertura16.dropna()
cobertura17 = cobertura17.dropna()
cobertura18 = cobertura18.dropna()
cobertura19 = cobertura19.dropna()
cobertura20 = cobertura20.dropna()

# %%
fig, ax = plt.subplots()
plt.rcParams['figure.figsize'] = (12,8)

anos = ['2015','2016','2017','2018','2019','2020']


for x in range(len(cobertura15.cobertura)):
    historico = [cobertura15.cobertura.iloc[x], 
                 cobertura16.cobertura.iloc[x], 
                 cobertura17.cobertura.iloc[x], 
                 cobertura18.cobertura.iloc[x], 
                 cobertura19.cobertura.iloc[x], 
                 cobertura20.cobertura.iloc[x]] 
    ax.plot(anos, historico, label=cobertura15.uf.iloc[x])
ax.legend(bbox_to_anchor=(1, 1))
plt.title('Porcentagem de cobertura da vacina nos últimos 5 anos no Brasil. (Separado por estado)')
plt.xlabel('Anos')
plt.ylabel('Porcentagem de cobertura')

plt.show()

# %%
fig, ax = plt.subplots()

anos = ['2015','2016','2017','2018','2019','2020']

#historico = [cobertura15.cobertura.iloc[0], cobertura16.cobertura.iloc[0], cobertura17.cobertura.iloc[0]]


for x in range(len(doseAplicada15.doses)):
    historico = [doseAplicada15.doses.iloc[x], 
                 doseAplicada16.doses.iloc[x], 
                 doseAplicada17.doses.iloc[x], 
                 doseAplicada18.doses.iloc[x], 
                 doseAplicada19.doses.iloc[x], 
                 doseAplicada20.doses.iloc[x]] 
    ax.plot(anos, historico, label=doseAplicada15.uf.iloc[x])
ax.legend(bbox_to_anchor=(1, 1))
plt.xlabel('Anos')
plt.ylabel('Quantidade de doses aplicadas (*10000)')
plt.title('Doses aplicadas de vacina nos últimos 5 anos no Brasil. (Separado por estado)')

plt.show()

# %%
fig, ax = plt.subplots()

anos = ['2015','2016','2017','2018','2019','2020']


for x in range(len(abandono15.taxa_abandono)):
    historico = [abandono15.taxa_abandono.iloc[x], 
                 abandono16.taxa_abandono.iloc[x], 
                 abandono17.taxa_abandono.iloc[x], 
                 abandono18.taxa_abandono.iloc[x], 
                 abandono19.taxa_abandono.iloc[x], 
                 abandono20.taxa_abandono.iloc[x]] 
    ax.plot(anos, historico, label=abandono15.uf.iloc[x])
ax.legend(bbox_to_anchor=(1, 1))
plt.xlabel('Anos')
plt.ylabel('Porcentagem de abandono')
plt.title('Taxa de abandono as vacinas nos últimos 5 anos no Brasil. (Separado por estado)')

plt.show()
